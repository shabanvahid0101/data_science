# %% [markdown]
# <a href="https://colab.research.google.com/github/shabanvahid0101/data_science/blob/main/determinal.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
from scipy.linalg import det

# %%
A = np.array([[2,0,1],
              [1,3,-1],
              [0,2,4]])
print(det(A))
# Out:
# 30.0

# %%
A = np.array([[],
              [],
              []])
print(det(A))
